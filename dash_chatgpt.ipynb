# %%
import dash
from dash import html
from dash import dcc
from dash.dependencies import Input, Output
import yfinance as yf
import pandas as pd
from prophet import Prophet
from statsmodels.tsa.arima.model import ARIMA

import numpy as np

app = dash.Dash(__name__)

app.layout = html.Div([
    html.H1("ChatGPT App"),
    html.Label("Enter Prompt:"),
    dcc.Input(id='prompt-input', type='text', value='Write an essay on AI and ethics'),
    html.Button('Submit', id='submit-val', n_clicks=0),
    html.Div(id='output-prediction')
])

@app.callback(
    Output('output-prediction', 'children'),
    Input('submit-val', 'n_clicks'),
    Input('prompt-input', 'value')
   
)
def update_output(n_clicks, prompt_input):
    import openai
    api_key="###Enter your key####"
    openai.api_key = api_key
    MODEL = "gpt-3.5-turbo"
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[

            {"role": "user", "content": prompt_input}
        ],
        temperature=0,
    )

    
  
    return html.Div([
        html.H2("ChatGPT response"),
        html.P(response.choices[0].message.content)
       
    ])

if __name__ == '__main__':
    app.run(debug=True)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 51
#      44     return html.Div([
#      45         html.H2("ChatGPT response"),
#      46         html.P(response.choices[0].message.content)
#      47
#      48     ])
#      50 if __name__ == '__main__':
# ---> 51     app.run_server(debug=True)
#
# File ~\anaconda3\lib\site-packages\dash\dash.py:2277, in Dash.run_server(self, *args, **kwargs)
#    2271 def run_server(self, *args, **kwargs):
#    2272     """`run_server` is a deprecated alias of `run` and may be removed in a
#    2273     future version. We recommend using `app.run` instead.
#    2274
#    2275     See `app.run` for usage information.
#    2276     """
# -> 2277     self.run(*args, **kwargs)
#
# ...
